# %%
# Jupyter Notebook용 코드입니다.

# %%
# !pip install selenium
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
import time
import os
from urllib.request import urlretrieve
import re

# %%
# 크롬 창 켜기
driver = wb.Chrome()

# %%
# 인스타그램 접속
driver.get("https://www.instagram.com/")

# %%
# 아이디 입력
inputid = driver.find_element(By.CSS_SELECTOR, "#loginForm > div > div:nth-child(1) > div > label > input")
inputid.send_keys("")

# 비밀번호 입력
inputpw = driver.find_element(By.CSS_SELECTOR, "#loginForm > div > div:nth-child(2) > div > label > input")
inputpw.send_keys("")

# %%
# 로그인 버튼 클릭
login = driver.find_element(By.CSS_SELECTOR, "#loginForm > div > div:nth-child(3) > button")
login.click()

# %%
# 키워드 검색
search = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_5N > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y > section > div > nav > div > header > div > div > div.xq8finb > div > div > div > div > div > div")
search.click()

# %%
search_2 = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_5N > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y > section > div > nav > div > header > div > div > div.xq8finb > div > div > div > div > div > input")
search_2.send_keys("Nestle")

# %%
search_3 = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_5N > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y > section > div > nav > div > header > div > div > div.xq8finb > div > div > div > div > div > div.x10l6tqk.x1ym02ve.x1vjfegm > div > div > div > div > div > div > a:nth-child(1) > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1pi30zi.x1swvt13.xwib8y2.x1y1aw1k.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div > div")
search_3.click()

# %%
# 댓글을 저장할 리스트
all_comments_1 = []

# 각 게시글을 순차적으로 클릭하고 댓글 수집
for row in range(1, 12):  # 1부터 11번째 행까지
    for col in range(1, 4):  # 각 행의 3개의 열
        try:
            # 게시글 CSS 선택자 생성
            post_css_selector = f"#mount_0_0_yw > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div:nth-child(2) > div > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y > section > main > div > div:nth-child(3) > div > div:nth-child({row}) > div:nth-child({col}) > a > div._aagu"
            
            # 게시글 클릭
            post = driver.find_element(By.CSS_SELECTOR, post_css_selector)
            post.click()
            time.sleep(3)  # 페이지 로드 대기

            # 스크롤 및 + 버튼 클릭
            for _ in range(3):
                try:
                    plus = driver.find_element(By.CSS_SELECTOR, "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.x15h9jz8.x47corl.xh8yej3.xir0mxb.x1juhsu6 > div > article > div > div.x1qjc9v5.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x78zum5.xdt5ytf.x1iyjqo2.x5wqa0o.xln7xf2.xk390pu.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x65f84u.x1vq45kp.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x11njtxf > div > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul > div:nth-child(3) > div > div > li > div > button > div > svg")
                    plus.click()
                    time.sleep(2)
                except NoSuchElementException:
                    print("There's no Plus Button.")
                    break
                except ElementClickInterceptedException:
                    pass

            # 댓글 수집 - find_element"s" 주의!!
            comment_elements = driver.find_elements(By.CSS_SELECTOR, "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.x15h9jz8.x47corl.xh8yej3.xir0mxb.x1juhsu6 > div > article > div > div.x1qjc9v5.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x78zum5.xdt5ytf.x1iyjqo2.x5wqa0o.xln7xf2.xk390pu.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x65f84u.x1vq45kp.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x11njtxf > div > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul > div:nth-child(3) > div > div > div > ul > div > li > div > div > div._a9zr > div._a9zs")
            comments = [comment.text for comment in comment_elements]
            all_comments_1.extend(comments)
            time.sleep(2)
            
            # 게시글 닫기
            back = driver.find_element(By.CSS_SELECTOR, "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x160vmok.x10l6tqk.x1eu8d0j.x1vjfegm > div > div > svg")
            back.click()
            time.sleep(2)  # 페이지 로드 대기

        except NoSuchElementException:
            print(f"No post found at row {row}, column {col}")
        except Exception as e:
            print(f"An error occurred at row {row}, column {col}: {e}")

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments_1)}")
all_comments_1
# Out:
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# There's no Plus Button.
# Total number of comments collected: 402
# ['Receipe 4 Life: Nestle',
#  '❤️👌',
#  'Sie haben Hundefutter verkauft was tausende Hunde umgebracht hat',
#  'Enteignen',
# ...

# %%
all_comments_2 = []

# 각 게시글을 순차적으로 클릭하고 댓글 수집
for row in range(1, 11):  # 11부터 20째 행까지
    for col in range(1, 4):  # 각 행의 3개의 열
        try:
            # 게시글 CSS 선택자 생성
            post_css_selector = f"#mount_0_0_fT > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div:nth-child(2) > div > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y > section > main > div > div:nth-child(3) > div > div:nth-child(row) > div:nth-child({col})"
            
            # 게시글 클릭
            post = driver.find_element(By.CSS_SELECTOR, post_css_selector)
            post.click()
            time.sleep(3)  # 페이지 로드 대기

            # 스크롤 및 + 버튼 클릭
            for _ in range(3):
                try:
                    plus = driver.find_element(By.CSS_SELECTOR, "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.x15h9jz8.x47corl.xh8yej3.xir0mxb.x1juhsu6 > div > article > div > div.x1qjc9v5.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x78zum5.xdt5ytf.x1iyjqo2.x5wqa0o.xln7xf2.xk390pu.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x65f84u.x1vq45kp.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x11njtxf > div > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul > div:nth-child(3) > div > div > li > div > button > div > svg")
                    plus.click()
                    time.sleep(2)
                except NoSuchElementException:
                    print("There's no Plus Button.")
                    break
                except ElementClickInterceptedException:
                    pass

            # 댓글 수집 - find_element"s" 주의!!
            comment_elements = driver.find_elements(By.CSS_SELECTOR, "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.x15h9jz8.x47corl.xh8yej3.xir0mxb.x1juhsu6 > div > article > div > div.x1qjc9v5.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x78zum5.xdt5ytf.x1iyjqo2.x5wqa0o.xln7xf2.xk390pu.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x65f84u.x1vq45kp.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x11njtxf > div > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul > div:nth-child(3) > div > div > div > ul > div > li > div > div > div._a9zr > div._a9zs")
            comments = [comment.text for comment in comment_elements]
            all_comments_2.extend(comments)
            time.sleep(2)
            
            # 게시글 닫기
            back = driver.find_element(By.CSS_SELECTOR, "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x160vmok.x10l6tqk.x1eu8d0j.x1vjfegm > div > div > svg")
            back.click()
            time.sleep(2)  # 페이지 로드 대기

        except NoSuchElementException:
            print(f"No post found at row {row}, column {col}")
        except Exception as e:
            print(f"An error occurred at row {row}, column {col}: {e}")

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments_2)}")
all_comments_2
# Out:
# An error occurred at row 1, column 1: Message: invalid selector
# from javascript error: {"status":32,"value":"An invalid or illegal selector was specified"}
#   (Session info: chrome=126.0.6478.128); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalid-selector-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF757BEEEB2+31554]
# 	(No symbol) [0x00007FF757B67EE9]
# 	(No symbol) [0x00007FF757A2872A]
# 	(No symbol) [0x00007FF757A2E55E]
# 	(No symbol) [0x00007FF757A30EB1]
# 	(No symbol) [0x00007FF757A30F50]
# 	(No symbol) [0x00007FF757A77F6C]
# 	(No symbol) [0x00007FF757A7853C]
# 	(No symbol) [0x00007FF757ABF6A7]
# 	(No symbol) [0x00007FF757A9D06F]
# 	(No symbol) [0x00007FF757ABC977]
# 	(No symbol) [0x00007FF757A9CDD3]
# 	(No symbol) [0x00007FF757A6A33B]
# 	(No symbol) [0x00007FF757A6AED1]
# 	GetHandleVerifier [0x00007FF757EF8B2D+3217341]
# 	GetHandleVerifier [0x00007FF757F45AF3+3532675]
# ...

# %%
all_comments_3 = []

# 각 게시글을 순차적으로 클릭하고 댓글 수집
for row in range(20, 30):  # 20부터 29번째 행까지
    for col in range(1, 4):  # 각 행의 3개의 열
        try:
            # 게시글 CSS 선택자 생성
            post_css_selector = f"#mount_0_0_HC > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div:nth-child(2) > div > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y > section > main > div > div:nth-child(3) > div > div:nth-child({row}) > div:nth-child({col}) > a > div._aagu > div._aagw"
            
            # 게시글 클릭
            post = driver.find_element(By.CSS_SELECTOR, post_css_selector)
            post.click()
            time.sleep(3)  # 페이지 로드 대기

            # 스크롤 및 + 버튼 클릭
            for _ in range(3):
                try:
                    plus = driver.find_element(By.CSS_SELECTOR, "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.x15h9jz8.x47corl.xh8yej3.xir0mxb.x1juhsu6 > div > article > div > div.x1qjc9v5.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x78zum5.xdt5ytf.x1iyjqo2.x5wqa0o.xln7xf2.xk390pu.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x65f84u.x1vq45kp.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x11njtxf > div > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul > div:nth-child(3) > div > div > li > div > button > div > svg")
                    plus.click()
                    time.sleep(2)
                except NoSuchElementException:
                    print("There's no Plus Button.")
                    break
                except ElementClickInterceptedException:
                    pass

            # 댓글 수집 - find_element"s" 주의!!
            comment_elements = driver.find_elements(By.CSS_SELECTOR, "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.x15h9jz8.x47corl.xh8yej3.xir0mxb.x1juhsu6 > div > article > div > div.x1qjc9v5.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x78zum5.xdt5ytf.x1iyjqo2.x5wqa0o.xln7xf2.xk390pu.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x65f84u.x1vq45kp.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x11njtxf > div > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul > div:nth-child(3) > div > div > div > ul > div > li > div > div > div._a9zr > div._a9zs")
            comments = [comment.text for comment in comment_elements]
            all_comments_3.extend(comments)
            time.sleep(2)
            
            # 게시글 닫기
            back = driver.find_element(By.CSS_SELECTOR, "body > div.x1n2onr6.xzkaem6 > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x160vmok.x10l6tqk.x1eu8d0j.x1vjfegm > div > div > svg")
            back.click()
            time.sleep(2)  # 페이지 로드 대기

        except NoSuchElementException:
            print(f"No post found at row {row}, column {col}")
        except Exception as e:
            print(f"An error occurred at row {row}, column {col}: {e}")

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments_3)}")
all_comments_3
