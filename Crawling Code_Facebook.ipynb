# %%
# Jupyter Notebook용 코드입니다.

# %%
# !pip install selenium
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
import time
import os
from urllib.request import urlretrieve
import re

# %%
# 크롬 창 켜기
driver = wb.Chrome()

# %%
# 페이스북 접속
driver.get("https://www.facebook.com/")

# %%
# 아이디 입력
inputid = driver.find_element(By.CSS_SELECTOR, "#email")
inputid.send_keys("")

# 비밀번호 입력
inputpw = driver.find_element(By.CSS_SELECTOR, "#pass")
inputpw.send_keys("")

# %%
# 로그인 버튼 클릭
login = driver.find_element(By.CSS_SELECTOR, "#u_0_5_B9")
login.click()

# %%
# 키워드 검색
search = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_A1 > div > div:nth-child(1) > div > div:nth-child(3) > div.x9f619.x1s65kcs.x16xn7b0.xixxii4.x17qophe.x13vifvy.xj35x94.xhtitgo.xmy5rp > div > div > div > div > div > label")
search.click()

# %%
search_2 = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_A1 > div > div:nth-child(1) > div > div:nth-child(3) > div.x9f619.x1s65kcs.x16xn7b0.xixxii4.x17qophe.x13vifvy.x1m258z3.xoegz02.xmy5rp.x1jx94hy > div > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.x1mh8g0r.xexx8yu.x18d9i69.x6s0dn4.x9f619.x78zum5.x1s65kcs.x1wsgfga.x1pi30zi.x1swvt13 > div > div > label > input")
search_2.send_keys("Nestle")

# %%
search_3 = driver.find_element(By.CSS_SELECTOR, "#hc_sts\:100053176971109 > div > a > div > div.x9f619.x1n2onr6.x1ja2u2z.x78zum5.xdt5ytf.x193iq5w.xeuugli.x1r8uery.x1iyjqo2.xs83m0k.xsyo7zv.x16hj40l.x10b6aqq.x1yrsyyn > div > div:nth-child(1) > span > span")
search_3.click()

# %%
# Nestle 계정 접속
search_4 = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_A1 > div > div:nth-child(1) > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.x2lah0s.x1nhvcw1.x1qjc9v5.xozqiw3.x1q0g3np.x78zum5.x1iyjqo2.x1t2pt76.x1n2onr6.x1ja2u2z.x1h6rjhl > div.x9f619.x1n2onr6.x1ja2u2z.xdt5ytf.x193iq5w.xeuugli.x1r8uery.x1iyjqo2.xs83m0k.x78zum5.x1t2pt76 > div > div > div > div > div > div.x1yztbdb > div > div > div > div > div > div > div > div > div > div > div > div:nth-child(1) > div > div.xamitd3.x1r8uery.x1iyjqo2.xs83m0k.xeuugli > div > div:nth-child(1) > h2 > span > span > span > a > span:nth-child(1)")
search_4.click()

# %%
# 스크롤하여 끝까지 게시글 로딩(100개 게시글의 댓글 수집 가능하도록)
for _ in range(15):
    scroll = driver.find_element(By.CSS_SELECTOR, "body")
    scroll.send_keys(Keys.END)
    time.sleep(2)

print("Target Posts are Loaded.")
# Out:
# Target Posts are Loaded.

# %%
all_comments = []
# 3~49번째 게시글
for post_no in range(3, 50):
    try:
        # 댓글 더보기 클릭
        more_selector = f"#mount_0_0_ho > div > div:nth-child(1) > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x78zum5.xdt5ytf.x1t2pt76 > div > div > div.x6s0dn4.x78zum5.xdt5ytf.x193iq5w > div.x9f619.x193iq5w.x1talbiv.x1sltb1f.x3fxtfs.x1swvt13.x1pi30zi.xw7yly9 > div > div.x9f619.x1n2onr6.x1ja2u2z.xeuugli.xs83m0k.x1xmf6yo.x1emribx.x1e56ztr.x1i64zmx.xjl7jj.x19h7ccj.xu9j1y6.x7ep2pv > div:nth-child(2) > div:nth-child({post_no}) > div > div > div > div > div > div > div > div > div > div > div:nth-child(2) > div > div > div:nth-child(4) > div > div > div.xzueoph > div.xdj266r.xktsk01.xat24cr.x1d52u69 > div > div.x1i10hfl.xjbqb8w.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.x13fuv20.xu3j5b3.x1q0q8m5.x26u7qi.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xdl72j9.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.xexx8yu.x18d9i69.xkhd6sd.x1n2onr6.x16tdsg8.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1o1ewxj.x3x9cwd.x1e5q0jg.x13rtm0m.x3nfvp2.x87ps6o.x1lku1pv.x1a2a7pz.x6s0dn4.xi81zsa.x1q0g3np.x1iyjqo2.xs83m0k.xsyo7zv > span > span"
        more = driver.find_element(By.CSS_SELECTOR, more_selector)
        more.click()
        time.sleep(3)
    except NoSuchElementException:
        print(f"Post no.{post_no} has just one comment.")
        continue
        
    # find_element"s"
    comment_elements = driver.find_elements(By.CSS_SELECTOR, "#mount_0_0_ho > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div.xb57i2i.x1q594ok.x5lxg6s.x78zum5.xdt5ytf.x6ikm8r.x1ja2u2z.x1pq812k.x1rohswg.xfk6m8.x1yqm8si.xjx87ck.xx8ngbg.xwo3gff.x1n2onr6.x1oyok0e.x1odjw0f.x1iyjqo2.xy5w88m > div.x78zum5.xdt5ytf.x1iyjqo2.x1n2onr6.xaci4zi.x129vozr > div > div > div.xwya9rg.x11i5rnm.x1e56ztr.x1mh8g0r.xh8yej3 > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x18d9i69.x1swvt13.x1pi30zi.x1n2onr6 > div.html-div.xe8uvvx.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1gslohp > div > div > div > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6 > div > div.x1r8uery.x1iyjqo2.x6ikm8r.x10wlt62.x1pi30zi > div:nth-child(1) > div.xv55zj0.x1vvkbs.x1rg5ohu.xxymvpz > div > div > div > span > div > div")
    comments = [comment.text for comment in comment_elements]
    all_comments.extend(comments)
    print(f"post no.{post_no} crawled complete.")
    time.sleep(1)

    # 게시글 닫기
    back = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_ho > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div:nth-child(1) > div > div:nth-child(3) > div")
    back.click()
    time.sleep(1.5)

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments)}")
all_comments
# Out:
# post no.3 crawled complete.
# post no.4 crawled complete.
# Post no.5 has just one comment.
# post no.6 crawled complete.
# post no.7 crawled complete.
# post no.8 crawled complete.
# post no.9 crawled complete.
# Post no.10 has just one comment.
# post no.11 crawled complete.
# Post no.12 has just one comment.
# post no.13 crawled complete.
# post no.14 crawled complete.
# post no.15 crawled complete.
# post no.16 crawled complete.
# post no.17 crawled complete.
# post no.18 crawled complete.
# post no.19 crawled complete.
# post no.20 crawled complete.
# post no.21 crawled complete.
# post no.22 crawled complete.
# post no.23 crawled complete.
# post no.24 crawled complete.
# post no.25 crawled complete.
# post no.26 crawled complete.
# post no.27 crawled complete.
# post no.28 crawled complete.
# post no.29 crawled complete.
# post no.30 crawled complete.
# post no.31 crawled complete.
# post no.32 crawled complete.
# post no.33 crawled complete.
# post no.34 crawled complete.
# ...

# %%
# 50 ~ 99번째 게시글
for post_no in range(50, 100):
    try:
        # 댓글 더보기 클릭
        more_selector = f"#mount_0_0_ho > div > div:nth-child(1) > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x78zum5.xdt5ytf.x1t2pt76 > div > div > div.x6s0dn4.x78zum5.xdt5ytf.x193iq5w > div.x9f619.x193iq5w.x1talbiv.x1sltb1f.x3fxtfs.x1swvt13.x1pi30zi.xw7yly9 > div > div.x9f619.x1n2onr6.x1ja2u2z.xeuugli.xs83m0k.x1xmf6yo.x1emribx.x1e56ztr.x1i64zmx.xjl7jj.x19h7ccj.xu9j1y6.x7ep2pv > div:nth-child(2) > div:nth-child({post_no}) > div > div > div > div > div > div > div > div > div > div > div:nth-child(2) > div > div > div:nth-child(4) > div > div > div.xzueoph > div.xdj266r.xktsk01.xat24cr.x1d52u69 > div > div.x1i10hfl.xjbqb8w.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.x13fuv20.xu3j5b3.x1q0q8m5.x26u7qi.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xdl72j9.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.xexx8yu.x18d9i69.xkhd6sd.x1n2onr6.x16tdsg8.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1o1ewxj.x3x9cwd.x1e5q0jg.x13rtm0m.x3nfvp2.x87ps6o.x1lku1pv.x1a2a7pz.x6s0dn4.xi81zsa.x1q0g3np.x1iyjqo2.xs83m0k.xsyo7zv > span > span"
        more = driver.find_element(By.CSS_SELECTOR, more_selector)
        more.click()
        time.sleep(3)
    except NoSuchElementException:
        print(f"Post no.{post_no} has just one comment.")
        continue
        
    # find_element"s"
    comment_elements = driver.find_elements(By.CSS_SELECTOR, "#mount_0_0_ho > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div.xb57i2i.x1q594ok.x5lxg6s.x78zum5.xdt5ytf.x6ikm8r.x1ja2u2z.x1pq812k.x1rohswg.xfk6m8.x1yqm8si.xjx87ck.xx8ngbg.xwo3gff.x1n2onr6.x1oyok0e.x1odjw0f.x1iyjqo2.xy5w88m > div.x78zum5.xdt5ytf.x1iyjqo2.x1n2onr6.xaci4zi.x129vozr > div > div > div.xwya9rg.x11i5rnm.x1e56ztr.x1mh8g0r.xh8yej3 > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x18d9i69.x1swvt13.x1pi30zi.x1n2onr6 > div.html-div.xe8uvvx.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1gslohp > div > div > div > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6 > div > div.x1r8uery.x1iyjqo2.x6ikm8r.x10wlt62.x1pi30zi > div:nth-child(1) > div.xv55zj0.x1vvkbs.x1rg5ohu.xxymvpz > div > div > div > span > div > div")
    comments = [comment.text for comment in comment_elements]
    all_comments.extend(comments)
    print(f"post no.{post_no} crawled complete.")
    time.sleep(1)

    # 게시글 닫기
    back = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_ho > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div:nth-child(1) > div > div:nth-child(3) > div")
    back.click()
    time.sleep(1.5)

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments)}")
all_comments
# Out:
# Post no.50 has just one comment.
# post no.51 crawled complete.
# post no.52 crawled complete.
# post no.53 crawled complete.
# post no.54 crawled complete.
# post no.55 crawled complete.
# Post no.56 has just one comment.
# post no.57 crawled complete.
# post no.58 crawled complete.
# post no.59 crawled complete.
# post no.60 crawled complete.
# post no.61 crawled complete.
# post no.62 crawled complete.
# post no.63 crawled complete.
# post no.64 crawled complete.
# post no.65 crawled complete.
# post no.66 crawled complete.
# post no.67 crawled complete.
# post no.68 crawled complete.
# post no.69 crawled complete.
# post no.70 crawled complete.
# post no.71 crawled complete.
# post no.72 crawled complete.
# post no.73 crawled complete.
# post no.74 crawled complete.
# post no.75 crawled complete.
# post no.76 crawled complete.
# post no.77 crawled complete.
# Post no.78 has just one comment.
# post no.79 crawled complete.
# post no.80 crawled complete.
# ...

# %%
# 100 ~ 144번째 게시글
for post_no in range(100, 145):
    try:
        # 댓글 더보기 클릭
        more_selector = f"#mount_0_0_ho > div > div:nth-child(1) > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x78zum5.xdt5ytf.x1t2pt76 > div > div > div.x6s0dn4.x78zum5.xdt5ytf.x193iq5w > div.x9f619.x193iq5w.x1talbiv.x1sltb1f.x3fxtfs.x1swvt13.x1pi30zi.xw7yly9 > div > div.x9f619.x1n2onr6.x1ja2u2z.xeuugli.xs83m0k.x1xmf6yo.x1emribx.x1e56ztr.x1i64zmx.xjl7jj.x19h7ccj.xu9j1y6.x7ep2pv > div:nth-child(2) > div:nth-child({post_no}) > div > div > div > div > div > div > div > div > div > div > div:nth-child(2) > div > div > div:nth-child(4) > div > div > div.xzueoph > div.xdj266r.xktsk01.xat24cr.x1d52u69 > div > div.x1i10hfl.xjbqb8w.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.x13fuv20.xu3j5b3.x1q0q8m5.x26u7qi.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xdl72j9.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.xexx8yu.x18d9i69.xkhd6sd.x1n2onr6.x16tdsg8.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1o1ewxj.x3x9cwd.x1e5q0jg.x13rtm0m.x3nfvp2.x87ps6o.x1lku1pv.x1a2a7pz.x6s0dn4.xi81zsa.x1q0g3np.x1iyjqo2.xs83m0k.xsyo7zv > span > span"
        more = driver.find_element(By.CSS_SELECTOR, more_selector)
        more.click()
        time.sleep(3)
    except NoSuchElementException:
        print(f"Post no.{post_no} has just one comment.")
        continue
        
    # find_element"s"
    comment_elements = driver.find_elements(By.CSS_SELECTOR, "#mount_0_0_ho > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div.xb57i2i.x1q594ok.x5lxg6s.x78zum5.xdt5ytf.x6ikm8r.x1ja2u2z.x1pq812k.x1rohswg.xfk6m8.x1yqm8si.xjx87ck.xx8ngbg.xwo3gff.x1n2onr6.x1oyok0e.x1odjw0f.x1iyjqo2.xy5w88m > div.x78zum5.xdt5ytf.x1iyjqo2.x1n2onr6.xaci4zi.x129vozr > div > div > div.xwya9rg.x11i5rnm.x1e56ztr.x1mh8g0r.xh8yej3 > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x18d9i69.x1swvt13.x1pi30zi.x1n2onr6 > div.html-div.xe8uvvx.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1gslohp > div > div > div > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6 > div > div.x1r8uery.x1iyjqo2.x6ikm8r.x10wlt62.x1pi30zi > div:nth-child(1) > div.xv55zj0.x1vvkbs.x1rg5ohu.xxymvpz > div > div > div > span > div > div")
    comments = [comment.text for comment in comment_elements]
    all_comments.extend(comments)
    print(f"post no.{post_no} crawled complete.")
    time.sleep(1)

    # 게시글 닫기
    back = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_ho > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div:nth-child(1) > div > div:nth-child(3) > div")
    back.click()
    time.sleep(1.5)

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments)}")
all_comments
# Out:
# post no.100 crawled complete.
# post no.101 crawled complete.
# post no.102 crawled complete.
# post no.103 crawled complete.
# post no.104 crawled complete.
# post no.105 crawled complete.
# post no.106 crawled complete.
# post no.107 crawled complete.
# post no.108 crawled complete.
# post no.109 crawled complete.
# post no.110 crawled complete.
# post no.111 crawled complete.
# post no.112 crawled complete.
# post no.113 crawled complete.
# post no.114 crawled complete.
# post no.115 crawled complete.
# post no.116 crawled complete.
# Post no.117 has just one comment.
# Post no.118 has just one comment.
# post no.119 crawled complete.
# post no.120 crawled complete.
# Post no.121 has just one comment.
# Post no.122 has just one comment.
# post no.123 crawled complete.
# post no.124 crawled complete.
# Post no.125 has just one comment.
# Post no.126 has just one comment.
# Post no.127 has just one comment.
# Post no.128 has just one comment.
# Post no.129 has just one comment.
# ...

# %%
# 145 ~ 176번째 게시글
all_comments_2 = []
for post_no in range(145, 177):
    try:
        # 댓글 더보기 클릭
        more_selector = f"#mount_0_0_Ij > div > div:nth-child(1) > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x78zum5.xdt5ytf.x1t2pt76 > div > div > div.x6s0dn4.x78zum5.xdt5ytf.x193iq5w > div.x9f619.x193iq5w.x1talbiv.x1sltb1f.x3fxtfs.x1swvt13.x1pi30zi.xw7yly9 > div > div.x9f619.x1n2onr6.x1ja2u2z.xeuugli.xs83m0k.x1xmf6yo.x1emribx.x1e56ztr.x1i64zmx.xjl7jj.x19h7ccj.xu9j1y6.x7ep2pv > div:nth-child(2) > div:nth-child({post_no}) > div > div > div > div > div > div > div > div > div > div > div:nth-child(2) > div > div > div:nth-child(4) > div > div > div.xzueoph > div.xdj266r.xktsk01.xat24cr.x1d52u69 > div > div.x1i10hfl.xjbqb8w.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.x13fuv20.xu3j5b3.x1q0q8m5.x26u7qi.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xdl72j9.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.xexx8yu.x18d9i69.xkhd6sd.x1n2onr6.x16tdsg8.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1o1ewxj.x3x9cwd.x1e5q0jg.x13rtm0m.x3nfvp2.x87ps6o.x1lku1pv.x1a2a7pz.x6s0dn4.xi81zsa.x1q0g3np.x1iyjqo2.xs83m0k.xsyo7zv > span > span"
        more = driver.find_element(By.CSS_SELECTOR, more_selector)
        more.click()
        time.sleep(3)
    except NoSuchElementException:
        print(f"Post no.{post_no} has just one comment.")
        continue
        
    # find_element"s"
    comment_elements = driver.find_elements(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div.xb57i2i.x1q594ok.x5lxg6s.x78zum5.xdt5ytf.x6ikm8r.x1ja2u2z.x1pq812k.x1rohswg.xfk6m8.x1yqm8si.xjx87ck.xx8ngbg.xwo3gff.x1n2onr6.x1oyok0e.x1odjw0f.x1iyjqo2.xy5w88m > div.x78zum5.xdt5ytf.x1iyjqo2.x1n2onr6.xaci4zi.x129vozr > div > div > div.xwya9rg.x11i5rnm.x1e56ztr.x1mh8g0r.xh8yej3 > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x18d9i69.x1swvt13.x1pi30zi.x1n2onr6 > div.html-div.xe8uvvx.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1gslohp > div > div > div > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6 > div > div.x1r8uery.x1iyjqo2.x6ikm8r.x10wlt62.x1pi30zi > div:nth-child(1) > div.xv55zj0.x1vvkbs.x1rg5ohu.xxymvpz > div > div > div > span > div > div")
    comments = [comment.text for comment in comment_elements]
    all_comments_2.extend(comments)
    print(f"post no.{post_no} crawled complete.")
    time.sleep(1)

    # 게시글 닫기
    back = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div:nth-child(1) > div > div:nth-child(3) > div")
    back.click()
    time.sleep(1.5)

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments_2)}")
# Out:
# post no.145 crawled complete.
# post no.146 crawled complete.
# post no.147 crawled complete.
# Post no.148 has just one comment.
# Post no.149 has just one comment.
# Post no.150 has just one comment.
# Post no.151 has just one comment.
# post no.152 crawled complete.
# post no.153 crawled complete.
# post no.154 crawled complete.
# post no.155 crawled complete.
# post no.156 crawled complete.
# post no.157 crawled complete.
# Post no.158 has just one comment.
# Post no.159 has just one comment.
# post no.160 crawled complete.
# post no.161 crawled complete.
# post no.162 crawled complete.
# Post no.163 has just one comment.
# post no.164 crawled complete.
# post no.165 crawled complete.
# post no.166 crawled complete.
# Post no.167 has just one comment.
# Post no.168 has just one comment.
# post no.169 crawled complete.
# Post no.170 has just one comment.
# post no.171 crawled complete.
# post no.172 crawled complete.
# post no.173 crawled complete.
# post no.174 crawled complete.
# ...

# %%
all_comments_2
# Out:
# ['Beautiful',
#  'Could you please provide your email for a business inquiry?',
#  'Bring back the drifter bar',
#  "Absolute disgrace! Open a brand new tub of quality street and not an equal number of any chocolate, what am I supposed to do with 4 yes FOUR green triangles, FIVE strawberry ones and 3 coins, not to mention the severely lacking number of fingers and purple ones! The rest are the ones nobody likes and should be removed with haste. These tubs cost an arm and a leg and are a nice treat for families at Christmas and you guys decide to completely lessen the amount of product in your tubs yet continue to charge more every year! What is going on, you have failed in your productivity this year Nestle. You don't even add the little booklet inside anymore! We never had this problem when quality street was made by Rowntree Mackintosh in 1969!",
#  'What a joyless box of confection Dairy Box is, a waste of Christmas calories and not fit to be labelled as chocolates.',
# ...

# %%
# 178 ~ 210번째 게시글
all_comments_3 = []
for post_no in range(178, 211):
    try:
        # 댓글 더보기 클릭
        more_selector = f"#mount_0_0_Ij > div > div:nth-child(1) > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x78zum5.xdt5ytf.x1t2pt76 > div > div > div.x6s0dn4.x78zum5.xdt5ytf.x193iq5w > div.x9f619.x193iq5w.x1talbiv.x1sltb1f.x3fxtfs.x1swvt13.x1pi30zi.xw7yly9 > div > div.x9f619.x1n2onr6.x1ja2u2z.xeuugli.xs83m0k.x1xmf6yo.x1emribx.x1e56ztr.x1i64zmx.xjl7jj.x19h7ccj.xu9j1y6.x7ep2pv > div:nth-child(2) > div:nth-child({post_no}) > div > div > div > div > div > div > div > div > div > div > div:nth-child(2) > div > div > div:nth-child(4) > div > div > div.xzueoph > div.xdj266r.xktsk01.xat24cr.x1d52u69 > div > div.x1i10hfl.xjbqb8w.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.x13fuv20.xu3j5b3.x1q0q8m5.x26u7qi.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xdl72j9.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.xexx8yu.x18d9i69.xkhd6sd.x1n2onr6.x16tdsg8.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1o1ewxj.x3x9cwd.x1e5q0jg.x13rtm0m.x3nfvp2.x87ps6o.x1lku1pv.x1a2a7pz.x6s0dn4.xi81zsa.x1q0g3np.x1iyjqo2.xs83m0k.xsyo7zv > span > span"
        more = driver.find_element(By.CSS_SELECTOR, more_selector)
        more.click()
        time.sleep(4)
    except NoSuchElementException:
        print(f"Post no.{post_no} has just one comment.")
        continue
        
    # find_element"s"
    comment_elements = driver.find_elements(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div.xb57i2i.x1q594ok.x5lxg6s.x78zum5.xdt5ytf.x6ikm8r.x1ja2u2z.x1pq812k.x1rohswg.xfk6m8.x1yqm8si.xjx87ck.xx8ngbg.xwo3gff.x1n2onr6.x1oyok0e.x1odjw0f.x1iyjqo2.xy5w88m > div.x78zum5.xdt5ytf.x1iyjqo2.x1n2onr6.xaci4zi.x129vozr > div > div > div.xwya9rg.x11i5rnm.x1e56ztr.x1mh8g0r.xh8yej3 > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x18d9i69.x1swvt13.x1pi30zi.x1n2onr6 > div.html-div.xe8uvvx.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1gslohp > div > div > div > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6 > div > div.x1r8uery.x1iyjqo2.x6ikm8r.x10wlt62.x1pi30zi > div:nth-child(1) > div.xv55zj0.x1vvkbs.x1rg5ohu.xxymvpz > div > div > div > span > div > div")
    comments = [comment.text for comment in comment_elements]
    all_comments_3.extend(comments)
    print(f"post no.{post_no} crawled complete.")
    time.sleep(1)

    # 게시글 닫기
    back = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div:nth-child(1) > div > div:nth-child(3) > div")
    back.click()
    time.sleep(3)

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments_3)}")
# Out:
# post no.178 crawled complete.
# post no.179 crawled complete.
# Post no.180 has just one comment.
# post no.181 crawled complete.
# Post no.182 has just one comment.
# post no.183 crawled complete.
# Post no.184 has just one comment.
# post no.185 crawled complete.
# post no.186 crawled complete.
# post no.187 crawled complete.
# post no.188 crawled complete.
# post no.189 crawled complete.
# post no.190 crawled complete.
# post no.191 crawled complete.
# post no.192 crawled complete.
# Post no.193 has just one comment.
# post no.194 crawled complete.
# post no.195 crawled complete.
# post no.196 crawled complete.
# Post no.197 has just one comment.
# post no.198 crawled complete.
# post no.199 crawled complete.
# Post no.200 has just one comment.
# post no.201 crawled complete.
# Post no.202 has just one comment.
# post no.203 crawled complete.
# post no.204 crawled complete.
# post no.205 crawled complete.
# post no.206 crawled complete.
# post no.207 crawled complete.
# ...

# %%
# 210 ~ 270번째 게시글
all_comments_4 = []
for post_no in range(210, 271):
    try:
        # 댓글 더보기 클릭
        more_selector = f"#mount_0_0_Ij > div > div:nth-child(1) > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x78zum5.xdt5ytf.x1t2pt76 > div > div > div.x6s0dn4.x78zum5.xdt5ytf.x193iq5w > div.x9f619.x193iq5w.x1talbiv.x1sltb1f.x3fxtfs.x1swvt13.x1pi30zi.xw7yly9 > div > div.x9f619.x1n2onr6.x1ja2u2z.xeuugli.xs83m0k.x1xmf6yo.x1emribx.x1e56ztr.x1i64zmx.xjl7jj.x19h7ccj.xu9j1y6.x7ep2pv > div:nth-child(2) > div:nth-child({post_no}) > div > div > div > div > div > div > div > div > div > div > div:nth-child(2) > div > div > div:nth-child(4) > div > div > div.xzueoph > div.xdj266r.xktsk01.xat24cr.x1d52u69 > div > div.x1i10hfl.xjbqb8w.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.x13fuv20.xu3j5b3.x1q0q8m5.x26u7qi.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xdl72j9.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.xexx8yu.x18d9i69.xkhd6sd.x1n2onr6.x16tdsg8.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1o1ewxj.x3x9cwd.x1e5q0jg.x13rtm0m.x3nfvp2.x87ps6o.x1lku1pv.x1a2a7pz.x6s0dn4.xi81zsa.x1q0g3np.x1iyjqo2.xs83m0k.xsyo7zv > span > span"
        more = driver.find_element(By.CSS_SELECTOR, more_selector)
        more.click()
        time.sleep(3)
    except NoSuchElementException:
        print(f"Post no.{post_no} has just one comment.")
        continue
        
    # find_element"s"
    comment_elements = driver.find_elements(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div.xb57i2i.x1q594ok.x5lxg6s.x78zum5.xdt5ytf.x6ikm8r.x1ja2u2z.x1pq812k.x1rohswg.xfk6m8.x1yqm8si.xjx87ck.xx8ngbg.xwo3gff.x1n2onr6.x1oyok0e.x1odjw0f.x1iyjqo2.xy5w88m > div.x78zum5.xdt5ytf.x1iyjqo2.x1n2onr6.xaci4zi.x129vozr > div > div > div.xwya9rg.x11i5rnm.x1e56ztr.x1mh8g0r.xh8yej3 > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x18d9i69.x1swvt13.x1pi30zi.x1n2onr6 > div.html-div.xe8uvvx.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1gslohp > div > div > div > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6 > div > div.x1r8uery.x1iyjqo2.x6ikm8r.x10wlt62.x1pi30zi > div:nth-child(1) > div.xv55zj0.x1vvkbs.x1rg5ohu.xxymvpz > div > div > div > span > div > div")
    comments = [comment.text for comment in comment_elements]
    all_comments_4.extend(comments)
    print(f"post no.{post_no} crawled complete.")
    time.sleep(1)

    # 게시글 닫기
    back = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div:nth-child(1) > div > div:nth-child(3) > div")
    back.click()
    time.sleep(1.5)

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments_4)}")
# Out:
# post no.210 crawled complete.
# post no.211 crawled complete.
# post no.212 crawled complete.
# Post no.213 has just one comment.
# post no.214 crawled complete.
# post no.215 crawled complete.
# post no.216 crawled complete.
# post no.217 crawled complete.
# post no.218 crawled complete.
# post no.219 crawled complete.
# Post no.220 has just one comment.
# post no.221 crawled complete.
# post no.222 crawled complete.
# post no.223 crawled complete.
# post no.224 crawled complete.
# post no.225 crawled complete.
# post no.226 crawled complete.
# post no.227 crawled complete.
# post no.228 crawled complete.
# post no.229 crawled complete.
# post no.230 crawled complete.
# post no.231 crawled complete.
# post no.232 crawled complete.
# Post no.233 has just one comment.
# post no.234 crawled complete.
# post no.235 crawled complete.
# post no.236 crawled complete.
# post no.237 crawled complete.
# post no.238 crawled complete.
# post no.239 crawled complete.
# ...

# %%
# 271 ~ 338번째 게시글
all_comments_5 = []
for post_no in range(271, 339):
    try:
        # 댓글 더보기 클릭
        more_selector = f"#mount_0_0_Ij > div > div:nth-child(1) > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x78zum5.xdt5ytf.x1t2pt76 > div > div > div.x6s0dn4.x78zum5.xdt5ytf.x193iq5w > div.x9f619.x193iq5w.x1talbiv.x1sltb1f.x3fxtfs.x1swvt13.x1pi30zi.xw7yly9 > div > div.x9f619.x1n2onr6.x1ja2u2z.xeuugli.xs83m0k.x1xmf6yo.x1emribx.x1e56ztr.x1i64zmx.xjl7jj.x19h7ccj.xu9j1y6.x7ep2pv > div:nth-child(2) > div:nth-child({post_no}) > div > div > div > div > div > div > div > div > div > div > div:nth-child(2) > div > div > div:nth-child(4) > div > div > div.xzueoph > div.xdj266r.xktsk01.xat24cr.x1d52u69 > div > div.x1i10hfl.xjbqb8w.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.x13fuv20.xu3j5b3.x1q0q8m5.x26u7qi.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xdl72j9.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.xexx8yu.x18d9i69.xkhd6sd.x1n2onr6.x16tdsg8.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1o1ewxj.x3x9cwd.x1e5q0jg.x13rtm0m.x3nfvp2.x87ps6o.x1lku1pv.x1a2a7pz.x6s0dn4.xi81zsa.x1q0g3np.x1iyjqo2.xs83m0k.xsyo7zv > span > span"
        more = driver.find_element(By.CSS_SELECTOR, more_selector)
        more.click()
        time.sleep(3)
    except NoSuchElementException:
        print(f"Post no.{post_no} has just one comment.")
        continue
        
    # find_element"s"
    comment_elements = driver.find_elements(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div.xb57i2i.x1q594ok.x5lxg6s.x78zum5.xdt5ytf.x6ikm8r.x1ja2u2z.x1pq812k.x1rohswg.xfk6m8.x1yqm8si.xjx87ck.xx8ngbg.xwo3gff.x1n2onr6.x1oyok0e.x1odjw0f.x1iyjqo2.xy5w88m > div.x78zum5.xdt5ytf.x1iyjqo2.x1n2onr6.xaci4zi.x129vozr > div > div > div.xwya9rg.x11i5rnm.x1e56ztr.x1mh8g0r.xh8yej3 > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x18d9i69.x1swvt13.x1pi30zi.x1n2onr6 > div.html-div.xe8uvvx.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1gslohp > div > div > div > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6 > div > div.x1r8uery.x1iyjqo2.x6ikm8r.x10wlt62.x1pi30zi > div:nth-child(1) > div.xv55zj0.x1vvkbs.x1rg5ohu.xxymvpz > div > div > div > span > div > div")
    comments = [comment.text for comment in comment_elements]
    all_comments_5.extend(comments)
    print(f"post no.{post_no} crawled complete.")
    time.sleep(1)

    # 게시글 닫기
    back = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div:nth-child(1) > div > div:nth-child(3) > div")
    back.click()
    time.sleep(1.5)

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments_5)}")
# Out:
# post no.271 crawled complete.
# post no.272 crawled complete.
# post no.273 crawled complete.
# post no.274 crawled complete.
# post no.275 crawled complete.
# post no.276 crawled complete.
# Post no.277 has just one comment.
# post no.278 crawled complete.
# post no.279 crawled complete.
# Post no.280 has just one comment.
# post no.281 crawled complete.
# post no.282 crawled complete.
# post no.283 crawled complete.
# post no.284 crawled complete.
# post no.285 crawled complete.
# post no.286 crawled complete.
# post no.287 crawled complete.
# Post no.288 has just one comment.
# post no.289 crawled complete.
# post no.290 crawled complete.
# Post no.291 has just one comment.
# Post no.292 has just one comment.
# Post no.293 has just one comment.
# post no.294 crawled complete.
# post no.295 crawled complete.
# post no.296 crawled complete.
# post no.297 crawled complete.
# post no.298 crawled complete.
# post no.299 crawled complete.
# post no.300 crawled complete.
# ...

# %%
# 346 ~ 372번째 게시글
all_comments_6 = []
for post_no in range(346, 373):
    try:
        # 댓글 더보기 클릭
        more_selector = f"#mount_0_0_Ij > div > div:nth-child(1) > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x78zum5.xdt5ytf.x1t2pt76 > div > div > div.x6s0dn4.x78zum5.xdt5ytf.x193iq5w > div.x9f619.x193iq5w.x1talbiv.x1sltb1f.x3fxtfs.x1swvt13.x1pi30zi.xw7yly9 > div > div.x9f619.x1n2onr6.x1ja2u2z.xeuugli.xs83m0k.x1xmf6yo.x1emribx.x1e56ztr.x1i64zmx.xjl7jj.x19h7ccj.xu9j1y6.x7ep2pv > div:nth-child(2) > div:nth-child({post_no}) > div > div > div > div > div > div > div > div > div > div > div:nth-child(2) > div > div > div:nth-child(4) > div > div > div.xzueoph > div.xdj266r.xktsk01.xat24cr.x1d52u69 > div > div.x1i10hfl.xjbqb8w.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.x13fuv20.xu3j5b3.x1q0q8m5.x26u7qi.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xdl72j9.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.xexx8yu.x18d9i69.xkhd6sd.x1n2onr6.x16tdsg8.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1o1ewxj.x3x9cwd.x1e5q0jg.x13rtm0m.x3nfvp2.x87ps6o.x1lku1pv.x1a2a7pz.x6s0dn4.xi81zsa.x1q0g3np.x1iyjqo2.xs83m0k.xsyo7zv > span > span"
        more = driver.find_element(By.CSS_SELECTOR, more_selector)
        more.click()
        time.sleep(3)
    except NoSuchElementException:
        print(f"Post no.{post_no} has just one comment.")
        continue
        
    # find_element"s"
    comment_elements = driver.find_elements(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div.xb57i2i.x1q594ok.x5lxg6s.x78zum5.xdt5ytf.x6ikm8r.x1ja2u2z.x1pq812k.x1rohswg.xfk6m8.x1yqm8si.xjx87ck.xx8ngbg.xwo3gff.x1n2onr6.x1oyok0e.x1odjw0f.x1iyjqo2.xy5w88m > div.x78zum5.xdt5ytf.x1iyjqo2.x1n2onr6.xaci4zi.x129vozr > div > div > div.xwya9rg.x11i5rnm.x1e56ztr.x1mh8g0r.xh8yej3 > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x18d9i69.x1swvt13.x1pi30zi.x1n2onr6 > div.html-div.xe8uvvx.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1gslohp > div > div > div > div > div.html-div.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6 > div > div.x1r8uery.x1iyjqo2.x6ikm8r.x10wlt62.x1pi30zi > div:nth-child(1) > div.xv55zj0.x1vvkbs.x1rg5ohu.xxymvpz > div > div > div > span > div > div")
    comments = [comment.text for comment in comment_elements]
    all_comments_6.extend(comments)
    print(f"post no.{post_no} crawled complete.")
    time.sleep(1)

    # 게시글 닫기
    back = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_Ij > div > div:nth-child(1) > div > div:nth-child(5) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div > div > div:nth-child(1) > div > div:nth-child(3) > div")
    back.click()
    time.sleep(1.5)

# 수집된 전체 댓글 수
print(f"Total number of comments collected: {len(all_comments_6)}")
# Out:
# post no.346 crawled complete.
# Post no.347 has just one comment.
# Post no.348 has just one comment.
# Post no.349 has just one comment.
# Post no.350 has just one comment.
# post no.351 crawled complete.
# Post no.352 has just one comment.
# post no.353 crawled complete.
# post no.354 crawled complete.
# Post no.355 has just one comment.
# post no.356 crawled complete.
# Post no.357 has just one comment.
# Post no.358 has just one comment.
# post no.359 crawled complete.
# Post no.360 has just one comment.
# post no.361 crawled complete.
# Post no.362 has just one comment.
# Post no.363 has just one comment.
# post no.364 crawled complete.
# post no.365 crawled complete.
# post no.366 crawled complete.
# Post no.367 has just one comment.
# post no.368 crawled complete.
# Post no.369 has just one comment.
# post no.370 crawled complete.
# post no.371 crawled complete.
# post no.372 crawled complete.
# Total number of comments collected: 54

# %%
# 데이터프레임화
import pandas as pd
all_comments_6_df_facebook = pd.DataFrame(all_comments_6)
all_comments_6_df_facebook.rename(columns={0: 'Comments'}, inplace=True)
all_comments_6_df_facebook
# Out:
#                                              Comments
# 0   Are you going to continue with the vegan KitKa...
# 1   Nestle trying to get in touch about your smart...
# 2   Did you know that Nespresso strength does not ...
# 3   branded kit Kat produce a fake and sell Kyrgyz...
# 4   Where are these in the UK? Only been able to p...
# 5                    Your company should be destroyed
# 6   Nestlé KitKat finger snap illustration by Vinc...
# 7   Nestlé when will u be revealing info on the Ir...
# 8                                 Still under an NDA?
# 9                                      I love\nnestle
# 10     Hi are your products suitable for vegetarians?
# 11                     Is the mahumarra Vegan please?
# 12                        Green washing at its finest
# 13                                              Super
# 14  And paying pennies for water then putting it i...
# 15  https://www.theguardian.com/.../ontario-six-na...
# ...

# %%
# 수집된 댓글 csv파일로 저장
# Visual Python: Data Analysis > File
all_comments_6_df_facebook.to_csv('./Crawled Comments from Facebook_6.csv')
